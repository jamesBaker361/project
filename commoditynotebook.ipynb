# %%
import pandas as pd
import numpy as np
from commodities import *

# %% [markdown]
# The Commodities are the Assets we are trading. There are a few dataframes we are using.

# %%
hard
# Out:
#             value_gold  value_oil  value_silver  value_ruth  value_irid  \
# Date
# 1992-07-01     343.400      21.90         4.045        32.0       200.0
# 1992-07-02     344.300      22.08         4.050        32.0       200.0
# 1992-07-03     346.130      22.08         4.060        32.0       200.0
# 1992-07-06     346.250      21.87         4.060        32.0       200.0
# 1992-07-07     346.550      21.51         4.060        32.0       200.0
# ...                ...        ...           ...         ...         ...
# 2020-03-25    1617.155      20.75        14.435       250.0      1510.0
# 2020-03-26    1605.405      16.60        14.320       250.0      1510.0
# 2020-03-27    1625.080      15.48        14.520       250.0      1510.0
# 2020-03-30    1620.540      14.10        14.050       260.0      1510.0
# 2020-03-31    1615.885      20.51        14.110       260.0      1520.0
#
#             value_pall  value_rhod  value_plat
# Date
# ...

# %% [markdown]
# The first one, hard, simply has prices from 1992 to present

# %%
hard_pct
# Out:
#             pct_gold   pct_oil  pct_silver  pct_ruth  pct_irid  pct_pall  \
# Date
# 1992-07-01  0.000000  0.000000    0.000000      0.00  0.000000  0.000000
# 1992-07-02  0.002621  0.008219    0.001236      0.00  0.000000  0.012048
# 1992-07-03  0.005315  0.000000    0.002469      0.00  0.000000  0.000000
# 1992-07-06  0.000347 -0.009511    0.000000      0.00  0.000000  0.000000
# 1992-07-07  0.000866 -0.016461    0.000000      0.00  0.000000 -0.011905
# ...              ...       ...         ...       ...       ...       ...
# 2020-03-25  0.026495 -0.013314    0.047533      0.00  0.000000  0.065217
# 2020-03-26 -0.007266 -0.200000   -0.007967      0.00  0.000000  0.128280
# 2020-03-27  0.012255 -0.067470    0.013966      0.00  0.000000  0.020241
# 2020-03-30 -0.002794 -0.089147   -0.032369      0.04  0.000000 -0.041368
# 2020-03-31 -0.002872  0.454610    0.004270      0.00  0.006623  0.029943
#
#             pct_rhod  pct_plat
# Date
# 1992-07-01  0.000000  0.000000
# ...

# %% [markdown]
# hard_pct is just the percent change in prices from one day to the next.

# %%
hard_tech
# Out:
#             macd_gold   rsi_gold  macd_oil    rsi_oil  macd_silver  \
# Date
# 1992-08-17  -2.015020  29.226935 -0.094782  47.454266    -0.035345
# 1992-08-18  -2.690971  28.547065 -0.078111  49.341053    -0.041041
# 1992-08-19  -3.166363  29.369062 -0.080911  44.212059    -0.044238
# 1992-08-20  -3.386270  33.449592 -0.076599  46.218918    -0.046239
# 1992-08-21  -3.545499  32.999592 -0.089100  41.406624    -0.049673
# ...               ...        ...       ...        ...          ...
# 2020-03-25 -15.526724  55.544042 -7.638467  28.285267    -1.201334
# 2020-03-26 -11.004244  53.711742 -7.882448  25.071727    -1.106779
# 2020-03-27  -5.766070  56.310680 -8.073118  24.270320    -1.004131
# 2020-03-30  -1.958543  55.535819 -8.240587  23.282790    -0.949758
# 2020-03-31   0.675543  54.704618 -7.766546  36.256746    -0.891549
#
#             rsi_silver  macd_ruth   rsi_ruth  macd_irid  rsi_irid   macd_pall  \
# Date
# ...

# %% [markdown]
# hard_tech contains the technical factors studied: the RSI and MACD of each asset
